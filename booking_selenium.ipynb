# %%
# url = 'https://www.booking.com/searchresults.en-us.html?ss={}&ssne={}&ssne_untouched={}&label=gen173nr-1FCAEoggI46AdIM1gEaKcCiAEBmAExuAEHyAEM2AEB6AEB-AECiAIBqAIDuALAzp6cBsACAdICJDFhMjc3YWQ4LTY3ZjktNDNhNy05NTI0LTUxMWY3NWQ2ODFmNdgCBeACAQ&sid=2126271f814d7c3f7af3ef0e5ea6d865&aid=304142&lang=en-us&sb=1&src_elem=sb&src=index&dest_id=2469&dest_type=region&checkin={}&checkout={}&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure'

# %%
import pandas as pd
import requests
import time
import re
from bs4 import BeautifulSoup
import selenium
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

# %%
from selenium.webdriver.common.keys import Keys

# %%
from selenium.webdriver import Chrome

# %%
path = '~/user/local/bin/chromedriver'

# %%
browser = Chrome()

# %%
url = "https://www.booking.com"

# %%
browser.get(url)

# %%
state_name=browser.find_element(By.NAME, "ss")

# %%
state_name.send_keys('New York')

# %%
dates = browser.find_element(By.XPATH, "//div[@class='xp__dates-inner']")

# %%
dates.click()

# %%
Month_next = browser.find_element(By.XPATH,"//div[@data-bui-ref='calendar-next']")

# %%
Month_next.click()

# %%
check_in = browser.find_element(By.XPATH,"//td[@data-date='2023-02-08']")

# %%
check_out = browser.find_element(By.XPATH,"//td[@data-date='2023-02-14']")

# %%
check_in.click()

# %%
check_out.click()

# %%
submitbutton = browser.find_element(By.XPATH, "//button[@type='submit']")

# %%
submitbutton.click()

# %%
property_cards = browser.find_elements(By.CSS_SELECTOR,'div[data-testid="property-card"]')

# %% [markdown]
# ### this is running till last page but only scraping the first page

# %%
base_url = 'https://www.booking.com/searchresults.html?label=gen173nr-1FCAEoggI46AdIM1gEaKcCiAEBmAExuAEHyAEM2AEB6AEB-AECiAIBqAIDuAKxi7-cBsACAdICJGM5ZDkyZTc4LTIxNDUtNDU3OS1iZDFlLWMxZjYwYjc1ODVhNtgCBeACAQ&sid=ea1a5e0393e11b9d3fd8c7662297d34e&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaKcCiAEBmAExuAEHyAEM2AEB6AEB-AECiAIBqAIDuAKxi7-cBsACAdICJGM5ZDkyZTc4LTIxNDUtNDU3OS1iZDFlLWMxZjYwYjc1ODVhNtgCBeACAQ%26sid%3Dea1a5e0393e11b9d3fd8c7662297d34e%26sb_price_type%3Dtotal%26%26&ss=New+York&is_ski_area=0&checkin_year=2023&checkin_month=2&checkin_monthday=8&checkout_year=2023&checkout_month=2&checkout_monthday=14&flex_window=0&efdco=1&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1&ss_raw=New+York&search_pageview_id=46459fd8a0990439'
listings = []
for properties in property_cards:
    listing = {}
    title = properties.find_element(By.CSS_SELECTOR,'div[data-testid="title"]').text
    address = properties.find_element(By.CSS_SELECTOR, '[data-testid="address"]').text
    price = properties.find_element(By.CSS_SELECTOR,'[data-testid="price-and-discounted-price"]').text
#     review_score_and_count = properties.find_element(By.CSS_SELECTOR,'[data-testid="review-score"]').text
    
    listing['title'] = title
    listing['address']= address
    listing['price'] = price
    listings.append(listing)

    
total_pages = int(browser.find_element(By.CSS_SELECTOR,'div[data-testid="pagination"] li:last-child').text)
print(f"Total pages: {total_pages}")
    
for i in range(1,22):
    page_url = ''.join([base_url,'&offset=',str(i*25)])
    print(page_url)
    next_page_btn = browser.find_element(By.XPATH,'//button[contains(@aria-label,"Next page")]')
    time.sleep(2)
    next_page_btn.click()
# Out:
# Total pages: 21
# https://www.booking.com/searchresults.html?label=gen173nr-1FCAEoggI46AdIM1gEaKcCiAEBmAExuAEHyAEM2AEB6AEB-AECiAIBqAIDuAKxi7-cBsACAdICJGM5ZDkyZTc4LTIxNDUtNDU3OS1iZDFlLWMxZjYwYjc1ODVhNtgCBeACAQ&sid=ea1a5e0393e11b9d3fd8c7662297d34e&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaKcCiAEBmAExuAEHyAEM2AEB6AEB-AECiAIBqAIDuAKxi7-cBsACAdICJGM5ZDkyZTc4LTIxNDUtNDU3OS1iZDFlLWMxZjYwYjc1ODVhNtgCBeACAQ%26sid%3Dea1a5e0393e11b9d3fd8c7662297d34e%26sb_price_type%3Dtotal%26%26&ss=New+York&is_ski_area=0&checkin_year=2023&checkin_month=2&checkin_monthday=8&checkout_year=2023&checkout_month=2&checkout_monthday=14&flex_window=0&efdco=1&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1&ss_raw=New+York&search_pageview_id=46459fd8a0990439&offset=25
# ...

# %%
listings
# Out:
# [{'title': 'Park Lane New York',
#   'address': 'Manhattan, New York',
#   'price': '$2,694$2,155\nOriginal price $2,694. Current price $2,155.'},
#  {'title': 'Millennium Downtown New York',
#   'address': 'Wall Street - Financial District, New York',
#   'price': '$944$802\nOriginal price $944. Current price $802.'},
#  {'title': 'Pod Times Square',
#   'address': "Hell's Kitchen, New York",
#   'price': '$774$658\nOriginal price $774. Current price $658.'},
#  {'title': 'SpringHill Suites by Marriott New York Manhattan Chelsea',
#   'address': 'Chelsea, New York',
#   'price': '$1,049\nPrice $1,049'},
#  {'title': 'Radisson Hotel New York Wall Street',
#   'address': 'Wall Street - Financial District, New York',
#   'price': '$856$727\nOriginal price $856. Current price $727.'},
#  {'title': '1597-7 Luxury Upper East Studio W&D in unit',
#   'address': 'Upper East Side, New York',
#   'price': '$780\nPrice $780'},
#  {'title': 'Pod 39',
#   'address': 'Murray Hill, New York',
# ...

# %%
i = 1
for i in range(0,22):
    page_url = ''.join([base_url,'&offset=',str(i*25)])
    print(page_url)
# Out:
# https://www.booking.com/searchresults.html?label=gen173nr-1FCAEoggI46AdIM1gEaKcCiAEBmAExuAEHyAEM2AEB6AEB-AECiAIBqAIDuAKxi7-cBsACAdICJGM5ZDkyZTc4LTIxNDUtNDU3OS1iZDFlLWMxZjYwYjc1ODVhNtgCBeACAQ&sid=ea1a5e0393e11b9d3fd8c7662297d34e&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaKcCiAEBmAExuAEHyAEM2AEB6AEB-AECiAIBqAIDuAKxi7-cBsACAdICJGM5ZDkyZTc4LTIxNDUtNDU3OS1iZDFlLWMxZjYwYjc1ODVhNtgCBeACAQ%26sid%3Dea1a5e0393e11b9d3fd8c7662297d34e%26sb_price_type%3Dtotal%26%26&ss=New+York&is_ski_area=0&checkin_year=2023&checkin_month=2&checkin_monthday=8&checkout_year=2023&checkout_month=2&checkout_monthday=14&flex_window=0&efdco=1&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1&ss_raw=New+York&search_pageview_id=46459fd8a0990439&offset=0
# ...

# %% [markdown]
# ### This code is running till last page but scraping same data.

# %%
from selenium import webdriver

from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
url = "https://www.booking.com/searchresults.html?label=gen173nr-1FCAEoggI46AdIM1gEaKcCiAEBmAExuAEHyAEM2AEB6AEB-AECiAIBqAIDuAKxi7-cBsACAdICJGM5ZDkyZTc4LTIxNDUtNDU3OS1iZDFlLWMxZjYwYjc1ODVhNtgCBeACAQ&sid=ea1a5e0393e11b9d3fd8c7662297d34e&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaKcCiAEBmAExuAEHyAEM2AEB6AEB-AECiAIBqAIDuAKxi7-cBsACAdICJGM5ZDkyZTc4LTIxNDUtNDU3OS1iZDFlLWMxZjYwYjc1ODVhNtgCBeACAQ%26sid%3Dea1a5e0393e11b9d3fd8c7662297d34e%26sb_price_type%3Dtotal%26%26&ss=New+York&is_ski_area=0&checkin_year=2023&checkin_month=2&checkin_monthday=8&checkout_year=2023&checkout_month=2&checkout_monthday=14&flex_window=0&efdco=1&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1&ss_raw=New+York&search_pageview_id=46459fd8a0990439'"
driver.get(url)

properties = []

def listings():
    property_cards = driver.find_elements(By.CSS_SELECTOR, 'div[data-testid="property-card"]')
    new_property = {}
    for property in property_cards:
        name = property.find_element(By.CSS_SELECTOR,'div[data-testid="title"]').text
        price = property.find_element(By.CSS_SELECTOR, '[data-testid="price-and-discounted-price"]').text
        address = property.find_element(By.CSS_SELECTOR, '[data-testid="address"]').text
        
        new_property['name'] = name
        new_property['price'] = price
        new_property['address'] = address
        properties.append(new_property)

total_pages = int(driver.find_element(By.CSS_SELECTOR, 'div[data-testid="pagination"]  li:last-child').text)
print(f"Total pages: {total_pages}")

for current_page in range(total_pages):
    listings()
    next_page_btn = driver.find_element(By.XPATH, '//button[contains(@aria-label, "Next page")]')
    next_page_btn.click()
    time.sleep(5)
# Out:
# Total pages: 21

# %%
properties
# Out:
# [{'name': 'Candlewood Suites NYC -Times Square, an IHG Hotel',
#   'price': '$654',
#   'address': "Hell's Kitchen, New York"},
#  {'name': 'Candlewood Suites NYC -Times Square, an IHG Hotel',
#   'price': '$654',
#   'address': "Hell's Kitchen, New York"},
#  {'name': 'Candlewood Suites NYC -Times Square, an IHG Hotel',
#   'price': '$654',
#   'address': "Hell's Kitchen, New York"},
#  {'name': 'Candlewood Suites NYC -Times Square, an IHG Hotel',
#   'price': '$654',
#   'address': "Hell's Kitchen, New York"},
#  {'name': 'Candlewood Suites NYC -Times Square, an IHG Hotel',
#   'price': '$654',
#   'address': "Hell's Kitchen, New York"},
#  {'name': 'Candlewood Suites NYC -Times Square, an IHG Hotel',
#   'price': '$654',
#   'address': "Hell's Kitchen, New York"},
#  {'name': 'Candlewood Suites NYC -Times Square, an IHG Hotel',
#   'price': '$654',
#   'address': "Hell's Kitchen, New York"},
#  {'name': 'Candlewood Suites NYC -Times Square, an IHG Hotel',
#   'price': '$654',
# ...

# %%
df = pd.DataFrame(properties)

# %%
df
# Out:
#                                                   name price  \
# 0    Candlewood Suites NYC -Times Square, an IHG Hotel  $654
# 1    Candlewood Suites NYC -Times Square, an IHG Hotel  $654
# 2    Candlewood Suites NYC -Times Square, an IHG Hotel  $654
# 3    Candlewood Suites NYC -Times Square, an IHG Hotel  $654
# 4    Candlewood Suites NYC -Times Square, an IHG Hotel  $654
# ..                                                 ...   ...
# 519  private room in a shared apartment 15 minutes ...  $846
# 520  private room in a shared apartment 15 minutes ...  $846
# 521  private room in a shared apartment 15 minutes ...  $846
# 522  private room in a shared apartment 15 minutes ...  $846
# 523  private room in a shared apartment 15 minutes ...  $846
#
#                       address
# 0    Hell's Kitchen, New York
# 1    Hell's Kitchen, New York
# 2    Hell's Kitchen, New York
# 3    Hell's Kitchen, New York
# 4    Hell's Kitchen, New York
# ..                        ...
# ...
